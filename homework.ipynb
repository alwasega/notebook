# %% [markdown]
# # 1. Create an Excel data table

# %%
import pandas as pd

excel_file = pd.read_excel("table.xlsx")

# %%
#Verifying the data types of the variables in the imported file 
excel_file.dtypes
# Out:
# Gender     object
# Weight      int64
# Height    float64
# dtype: object

# %%
#Displaying the data from within Python
excel_file
# Out:
#   Gender  Weight  Height
# 0      F     150    66.0
# 1      F     138    66.0
# 2      M     240     NaN
# 3      M     178    71.0
# 4      F     130    64.0
# 5      M     200    74.0
# 6      F     140    70.0
# 7      M     220    77.0

# %% [markdown]
# # 2. Large data set

# %%
#Reading the data into python
csv_file = pd.read_csv("Donations.csv")
csv_file
# Out:
#                      Name  Donation  Lifetime  Gifts  YearsSinceFirst  \
# 0            Yandel Leach       0.0     81.00     15         6.416667
# 1             Jaylah Sims      15.0     15.00      1         1.166667
# 2              Roger Bush       0.0     15.00      1         1.750000
# 3             Maddox Horn       0.0     25.00      2         3.500000
# 4         Darrell Walters       0.0     20.00      1         1.333333
# 5               Nick Kent       0.0     68.00      6         7.000000
# 6            Isabel Curry       0.0    110.00     11        10.166667
# 7               Levi Leon       0.0    174.00     26        10.416667
# 8           Zack Bradshaw       0.0     20.00      1         1.750000
# 9           Jessie Nguyen      14.0     95.00      7         6.083333
# 10             Angel Knox       0.0    111.00      5         4.166667
# 11     Giancarlo Phillips       0.0    174.00     15         9.083333
# ...

# %%
#Getting the number of rows and columns
csv_file.shape  #20,000 rows, 27 columns
# Out:
# (20000, 27)

# %%
#Listing the first ten rows of data and the variable names
csv_file.head(10)
# Out:
#               Name  Donation  Lifetime  Gifts  YearsSinceFirst  \
# 0     Yandel Leach       0.0      81.0     15         6.416667
# 1      Jaylah Sims      15.0      15.0      1         1.166667
# 2       Roger Bush       0.0      15.0      1         1.750000
# 3      Maddox Horn       0.0      25.0      2         3.500000
# 4  Darrell Walters       0.0      20.0      1         1.333333
# 5        Nick Kent       0.0      68.0      6         7.000000
# 6     Isabel Curry       0.0     110.0     11        10.166667
# 7        Levi Leon       0.0     174.0     26        10.416667
# 8    Zack Bradshaw       0.0      20.0      1         1.750000
# 9    Jessie Nguyen      14.0      95.0      7         6.083333
#
#    YearsSinceLast    AvgGift MajorDonor  Promotions  RecentGifts  ...  \
# 0        1.166667   5.400000         No          58            3  ...
# 1        1.166667  15.000000         No          13            1  ...
# ...

# %%
#Using python to identify numeric and character variables
csv_file.dtypes
#numeric variables are represented as floats or integers 
#while character variables are represented as objects
# Out:
# Name                object
# Donation           float64
# Lifetime           float64
# Gifts                int64
# YearsSinceFirst    float64
# YearsSinceLast     float64
# AvgGift            float64
# MajorDonor          object
# Promotions           int64
# RecentGifts          int64
# Age                float64
# HomePhone           object
# PCOwner             object
# CatalogShopper       int64
# PerCapIncome         int64
# MedHouseInc          int64
# Professional       float64
# Technical          float64
# Sales              float64
# Clerical           float64
# Farmers            float64
# SelfEmployed       float64
# Cars               float64
# OwnerOccupied      float64
# Age55_59           float64
# Age60_64           float64
# School             float64
# dtype: object
